# %%
#importing Libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')

# %%
df=pd.read_csv("aggregate_covid_country.csv")
df
# Out:
#              Date             Country  Confirmed  Recovered  Deaths
# 0      2020-01-22         Afghanistan          0          0       0
# 1      2020-01-22             Albania          0          0       0
# 2      2020-01-22             Algeria          0          0       0
# 3      2020-01-22             Andorra          0          0       0
# 4      2020-01-22              Angola          0          0       0
# ...           ...                 ...        ...        ...     ...
# 23683  2020-05-26  West Bank and Gaza        429        365       3
# 23684  2020-05-26      Western Sahara          9          6       1
# 23685  2020-05-26               Yemen        249         10      49
# 23686  2020-05-26              Zambia        920        336       7
# 23687  2020-05-26            Zimbabwe         56         25       4
#
# [23688 rows x 5 columns]

# %%
#Giving a glance to records by looking at first 5 rows
df.head()
# Out:
#          Date      Country  Confirmed  Recovered  Deaths
# 0  2020-01-22  Afghanistan          0          0       0
# 1  2020-01-22      Albania          0          0       0
# 2  2020-01-22      Algeria          0          0       0
# 3  2020-01-22      Andorra          0          0       0
# 4  2020-01-22       Angola          0          0       0

# %%
#Giving a glance to records by looking at last 5 rows
df.tail()
# Out:
#              Date             Country  Confirmed  Recovered  Deaths
# 23683  2020-05-26  West Bank and Gaza        429        365       3
# 23684  2020-05-26      Western Sahara          9          6       1
# 23685  2020-05-26               Yemen        249         10      49
# 23686  2020-05-26              Zambia        920        336       7
# 23687  2020-05-26            Zimbabwe         56         25       4

# %%
df.shape
# Out:
# (23688, 5)

# %%
#finding the meta data of data
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 23688 entries, 0 to 23687
# Data columns (total 5 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   Date       23688 non-null  object
#  1   Country    23688 non-null  object
#  2   Confirmed  23688 non-null  int64
#  3   Recovered  23688 non-null  int64
#  4   Deaths     23688 non-null  int64
# dtypes: int64(3), object(2)
# memory usage: 925.4+ KB

# %% [markdown]
# From the given data, we find out that there is no null value present in any attribute.

# %%
#finding columns in the dataset
df.columns
# Out:
# Index(['Date', 'Country', 'Confirmed', 'Recovered', 'Deaths'], dtype='object')

# %%
#finding count of countries present in dataset
df['Country'].value_counts()
# Out:
# Comoros                             126
# Saint Vincent and the Grenadines    126
# Cabo Verde                          126
# Angola                              126
# Ethiopia                            126
#                                    ...
# Iceland                             126
# Eritrea                             126
# Jamaica                             126
# Bolivia                             126
# Cameroon                            126
# Name: Country, Length: 188, dtype: int64

# %% [markdown]
# Observation: There are 126 dates recorded for each country.

# %%
#Is there any null value present in the dataset.
df.isnull().sum()
# Out:
# Date         0
# Country      0
# Confirmed    0
# Recovered    0
# Deaths       0
# dtype: int64

# %%
#getting the cases for india
India_cases=df[df['Country']=='India']
India_cases
# Out:
#              Date Country  Confirmed  Recovered  Deaths
# 79     2020-01-22   India          0          0       0
# 267    2020-01-23   India          0          0       0
# 455    2020-01-24   India          0          0       0
# 643    2020-01-25   India          0          0       0
# 831    2020-01-26   India          0          0       0
# ...           ...     ...        ...        ...     ...
# 22827  2020-05-22   India     124794      51824    3726
# 23015  2020-05-23   India     131423      54385    3868
# 23203  2020-05-24   India     138536      57692    4024
# 23391  2020-05-25   India     144950      60706    4172
# 23579  2020-05-26   India     150793      64277    4344
#
# [126 rows x 5 columns]

# %%
#getting the idea of dates in india
India_cases.head()
# Out:
#            Date Country  Confirmed  Recovered  Deaths
# 79   2020-01-22   India          0          0       0
# 267  2020-01-23   India          0          0       0
# 455  2020-01-24   India          0          0       0
# 643  2020-01-25   India          0          0       0
# 831  2020-01-26   India          0          0       0

# %%
India_cases.tail()
# Out:
#              Date Country  Confirmed  Recovered  Deaths
# 22827  2020-05-22   India     124794      51824    3726
# 23015  2020-05-23   India     131423      54385    3868
# 23203  2020-05-24   India     138536      57692    4024
# 23391  2020-05-25   India     144950      60706    4172
# 23579  2020-05-26   India     150793      64277    4344

# %%
#total cases per day
sns.set(rc={'figure.figsize':(15,10)})
sns.lineplot(x="Date",y="Confirmed",data=India_cases)

plt.show()

# %% [markdown]
# Observation: The above line graph shows that there is a exponential growth in case after a particular date. This shows that people are not following the particular measures imposed by govt such as social distancing, wearing mask,..etc. People should stay at home, which helps in less spread of disease.

# %%
#making dataframe for last 10 days cases in India
India_last_5days=India_cases.tail(10)
India_last_5days
# Out:
#              Date Country  Confirmed  Recovered  Deaths
# 21887  2020-05-17   India      95698      36795    3025
# 22075  2020-05-18   India     100328      39233    3156
# 22263  2020-05-19   India     106475      42309    3302
# 22451  2020-05-20   India     112028      45422    3434
# 22639  2020-05-21   India     118226      48553    3584
# 22827  2020-05-22   India     124794      51824    3726
# 23015  2020-05-23   India     131423      54385    3868
# 23203  2020-05-24   India     138536      57692    4024
# 23391  2020-05-25   India     144950      60706    4172
# 23579  2020-05-26   India     150793      64277    4344

# %%
#Visualizing last 10 days cases in India
sns.set(rc={'figure.figsize':(15,10)})
sns.lineplot(x="Date",y="Confirmed",data=India_last_5days)

plt.show()

# %% [markdown]
# Observation: The above graph shows that there is a rapid increase in number of cases in last 10 days. It is showing linear relation between cases and days. There is a major consern here because the cases keep on increasing day by day.

# %%
#plotting growth in India, China, Japan, USA 
I_C_J_U=df[(df['Country']=='India')|(df['Country']=='China')|(df['Country']=='Japan')|(df['Country']=='US')|(df['Country']=='Spain')|(df['Country']=='Germany')]
I_C_J_U
# Out:
#              Date  Country  Confirmed  Recovered  Deaths
# 36     2020-01-22    China        548         28      17
# 66     2020-01-22  Germany          0          0       0
# 79     2020-01-22    India          0          0       0
# 87     2020-01-22    Japan          2          0       0
# 158    2020-01-22    Spain          0          0       0
# ...           ...      ...        ...        ...     ...
# 23566  2020-05-26  Germany     181200     161967    8372
# 23579  2020-05-26    India     150793      64277    4344
# 23587  2020-05-26    Japan      16623      13810     846
# 23658  2020-05-26    Spain     236259     150376   27117
# 23674  2020-05-26       US    1680913     384902   98913
#
# [756 rows x 5 columns]

# %%
sns.set(rc={'figure.figsize':(10,10)})
sns.barplot(x="Country",y="Confirmed",data=I_C_J_U)

plt.show()

# %% [markdown]
# Observation: From the above graph we get to know that there are maximum confirmed cases in united states. India is still in better stage as compare to other countries. Reason behind higher number of cases in US is due to delay in taking necessary measures.

# %%
#Getting Latest data
last_day_cases=df[df['Date']=='2020-05-26']
last_day_cases
# Out:
#              Date             Country  Confirmed  Recovered  Deaths
# 23500  2020-05-26         Afghanistan      11831       1128     220
# 23501  2020-05-26             Albania       1029        803      33
# 23502  2020-05-26             Algeria       8697       4918     617
# 23503  2020-05-26             Andorra        763        676      51
# 23504  2020-05-26              Angola         70         18       4
# ...           ...                 ...        ...        ...     ...
# 23683  2020-05-26  West Bank and Gaza        429        365       3
# 23684  2020-05-26      Western Sahara          9          6       1
# 23685  2020-05-26               Yemen        249         10      49
# 23686  2020-05-26              Zambia        920        336       7
# 23687  2020-05-26            Zimbabwe         56         25       4
#
# [188 rows x 5 columns]

# %%
#sorting data to get the countries having highest number of cases
max_cases_coun =last_day_cases.sort_values(by="Confirmed",ascending=False)
max_cases_coun
# Out:
#              Date           Country  Confirmed  Recovered  Deaths
# 23674  2020-05-26                US    1680913     384902   98913
# 23523  2020-05-26            Brazil     391222     158593   24512
# 23640  2020-05-26            Russia     362342     131129    3807
# 23678  2020-05-26    United Kingdom     266599       1161   37130
# 23658  2020-05-26             Spain     236259     150376   27117
# ...           ...               ...        ...        ...     ...
# 23661  2020-05-26          Suriname         11          9       1
# 23604  2020-05-26        MS Zaandam          9          0       2
# 23684  2020-05-26    Western Sahara          9          6       1
# 23632  2020-05-26  Papua New Guinea          8          8       0
# 23598  2020-05-26           Lesotho          2          0       0
#
# [188 rows x 5 columns]

# %%
#finding top 10 countries having maximum number of cases
max_cases_coun[0:11]
# Out:
#              Date         Country  Confirmed  Recovered  Deaths
# 23674  2020-05-26              US    1680913     384902   98913
# 23523  2020-05-26          Brazil     391222     158593   24512
# 23640  2020-05-26          Russia     362342     131129    3807
# 23678  2020-05-26  United Kingdom     266599       1161   37130
# 23658  2020-05-26           Spain     236259     150376   27117
# 23585  2020-05-26           Italy     230555     144658   32955
# 23562  2020-05-26          France     182847      65997   28533
# 23566  2020-05-26         Germany     181200     161967    8372
# 23673  2020-05-26          Turkey     158762     121507    4397
# 23579  2020-05-26           India     150793      64277    4344
# 23581  2020-05-26            Iran     139511     109437    7508

# %%
#visualizing the data of these countries having maximum number of cases by using bargraph

sns.barplot(x='Country',y='Confirmed',color='r',data=max_cases_coun[0:11])
sns.barplot(x='Country',y='Recovered',color='g',data=max_cases_coun[0:11])
sns.barplot(x='Country',y='Deaths',color='b',data=max_cases_coun[0:11])

plt.show()

# %% [markdown]
# Observation: On observing the given graph we get to know that In US there are maximum number of cases where as in Iran there are less number of cases as compare to these countries. In US the recovery rate is also high as compare to other countries. Death rate in US, Italy,France, Brazil,Spain, Uk are more as compare to other countries. May be in these countries people have very less imunities to fight against disease or these countries have shortage of medical facilities due to exponential growth in number of patients.Here, the india has very less death rate.

# %%
#Applying the model by importing sklearn library
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split

# %%
#converting string date to date-time
import datetime as dt
India_cases['Date']=pd.to_datetime(India_cases['Date'])
India_cases.head()
# Out:
#           Date Country  Confirmed  Recovered  Deaths
# 79  2020-01-22   India          0          0       0
# 267 2020-01-23   India          0          0       0
# 455 2020-01-24   India          0          0       0
# 643 2020-01-25   India          0          0       0
# 831 2020-01-26   India          0          0       0

# %%
#converting date-time to ordinals
India_cases['Date']=India_cases['Date'].map(dt.datetime.toordinal)
India_cases.head()
# Out:
#        Date Country  Confirmed  Recovered  Deaths
# 79   737446   India          0          0       0
# 267  737447   India          0          0       0
# 455  737448   India          0          0       0
# 643  737449   India          0          0       0
# 831  737450   India          0          0       0

# %%
#getting dependent and independent variables
x=India_cases['Date']
x=np.array(x).reshape(-1,1)
y=India_cases['Confirmed']
y=np.array(y).reshape(-1,1)

# %%
#finding random state at which we get best results
from sklearn.metrics import r2_score
from sklearn import linear_model
max_r_score=0
for r_state in range(42,100):
    x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=.33,random_state=r_state)
    regr=linear_model.LinearRegression()
    regr.fit(x_train,y_train)
    y_pred=regr.predict(x_test)
    r2_scr=r2_score(y_test,y_pred)
    if r2_scr>max_r_score:
        max_r_score=r2_scr
        final_r_state=r_state
print("max r2 score corresponding to",final_r_state,"is",max_r_score)
# Out:
# max r2 score corresponding to 65 is 0.6513440186461297

# %%
#Lets use cross val score function to check above is overfitting or not
from sklearn.model_selection import cross_val_score
a_score=cross_val_score(linear_model.LinearRegression(),x,y,cv=5,scoring="r2").mean()
a_score
# Out:
# -228469921.495344

# %%
#Lets make our final model
x_train,x_test,y_train,y_test=train_test_split(x,y,random_state=65,test_size=0.20)
lr=linear_model.LinearRegression()
lr.fit(x_train,y_train)
y_pred=lr.predict(x_test)

# %%
#lets find the rmse and r2_score using sklearn.metrics
from sklearn.metrics import r2_score
from sklearn.metrics import mean_squared_error
print('RMSE is',np.sqrt(mean_squared_error(y_test,y_pred)))
print('r2_score is:',r2_score(y_test,y_pred))
# Out:
# RMSE is 19302.511712306332
# r2_score is: 0.6925019035102253

# %%
#lets use grid_search to find optimal value of n_neighbors for KNN model
from sklearn.model_selection import GridSearchCV
from sklearn.neighbors import KNeighborsRegressor
neighbors={"n_neighbors":range(1,30)}
knr=KNeighborsRegressor()
gknr=GridSearchCV(knr,neighbors,cv=10)
gknr.fit(x,y)
gknr.best_params_
# Out:
# {'n_neighbors': 1}

# %%
#importing algorithms
from sklearn.svm import SVR
from sklearn.tree import DecisionTreeRegressor
from sklearn.ensemble import RandomForestRegressor
from sklearn.ensemble import AdaBoostRegressor

# %%
#finding best parameter for RandomForestRegressor by using gridsearch cv

def Grid_Search_CV_RFR(x_train, y_train):
    from sklearn.model_selection import GridSearchCV
    from sklearn.model_selection import ShuffleSplit
    from sklearn.ensemble import RandomForestRegressor

    estimator = RandomForestRegressor()
    param_grid = { 
            "n_estimators"      : [10,20,30],
            "max_features"      : ["auto", "sqrt", "log2"],
            "min_samples_split" : [2,4,8],
            "bootstrap": [True, False],
            }

    grid = GridSearchCV(estimator, param_grid, n_jobs=-1, cv=5)

    grid.fit(x_train, y_train)

    return grid.best_score_ , grid.best_params_

# %%
def RFR(x_train, x_test, y_train, y_test, best_params):
    from sklearn.ensemble import RandomForestRegressor
    estimator = RandomForestRegressor(n_jobs=-1).set_params(**best_params)
    estimator.fit(x_train,y_train)
    y_predict = estimator.predict(x_test)
    print ("R2 score:",r2_score(y_test,y_predict))
    return y_test,y_predict

# %%
for i in range(5):
    print ("Loop: " , i)
    print ("--------------") 
    x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.2)
    best_score, best_params = Grid_Search_CV_RFR(x_train, y_train)
    y_test , y_predict = RFR(x_train, x_test, y_train, y_test, best_params)
    print ("Best Score:" ,best_score)
    print ("Best params:",best_params)
# Out:
# Loop:  0
# --------------
# R2 score: 0.9961615306500692
# Best Score: 0.994113670888178
# Best params: {'bootstrap': True, 'max_features': 'log2', 'min_samples_split': 2, 'n_estimators': 20}
# Loop:  1
# --------------
# R2 score: 0.9977033631562231
# Best Score: 0.9979350313515287
# Best params: {'bootstrap': True, 'max_features': 'auto', 'min_samples_split': 2, 'n_estimators': 10}
# Loop:  2
# --------------
# R2 score: 0.9989366868282398
# Best Score: 0.9982701412651647
# Best params: {'bootstrap': True, 'max_features': 'log2', 'min_samples_split': 2, 'n_estimators': 30}
# Loop:  3
# --------------
# R2 score: 0.9992017995073265
# Best Score: 0.9976592479877808
# Best params: {'bootstrap': True, 'max_features': 'sqrt', 'min_samples_split': 2, 'n_estimators': 10}
# Loop:  4
# --------------
# R2 score: 0.9991916875321738
# Best Score: 0.9961406986077936
# Best params: {'bootstrap': True, 'max_features': 'auto', 'min_samples_split': 2, 'n_estimators': 20}

# %%
dtm = DecisionTreeRegressor(max_depth=4,
                           min_samples_split=5,
                           max_leaf_nodes=10)


param_grid = {"criterion": ["mse", "mae"],
              "min_samples_split": [10, 20, 40],
              "max_depth": [2, 6, 8],
              "min_samples_leaf": [20, 40, 100],
              "max_leaf_nodes": [5, 20, 100],
              }

## Comment in order to publish in kaggle.

grid_cv_dtm = GridSearchCV(dtm, param_grid, cv=5)

grid_cv_dtm.fit(x,y)
print("R-Squared::{}".format(grid_cv_dtm.best_score_))
print("Best Hyperparameters::\n{}".format(grid_cv_dtm.best_params_))
# Out:
# R-Squared::-93.96921350717841
# Best Hyperparameters::
# {'criterion': 'mae', 'max_depth': 6, 'max_leaf_nodes': 5, 'min_samples_leaf': 20, 'min_samples_split': 10}

# %%
#finding best parameter for adaboost by using grid search cv
from sklearn.ensemble import AdaBoostRegressor
n_estimators={"n_estimators":range(1,30)}
ad=AdaBoostRegressor()
gad=GridSearchCV(ad,n_estimators,cv=10)
gad.fit(x,y)
gad.best_params_
# Out:
# {'n_estimators': 1}

# %%
from sklearn.linear_model import Ridge
ridge_reg = Ridge()
from sklearn.model_selection import GridSearchCV
params_Ridge = {'alpha': [1,0.1,0.01,0.001,0.0001,0] , "fit_intercept": [True, False], "solver": ['svd', 'cholesky', 'lsqr', 'sparse_cg', 'sag', 'saga']}
Ridge_GS = GridSearchCV(ridge_reg, param_grid=params_Ridge, n_jobs=-1)
Ridge_GS.fit(x,y)
Ridge_GS.best_params_
# Out:
# {'alpha': 0.0001, 'fit_intercept': False, 'solver': 'saga'}

# %%
#applying for loop for all the models
from sklearn.linear_model import LinearRegression
knr=KNeighborsRegressor(n_neighbors=1)
svr=SVR(C= 10, kernel= 'linear')
lr=LinearRegression()
dtr=DecisionTreeRegressor(criterion= 'mae', max_depth= 6, max_leaf_nodes= 5, min_samples_leaf= 20, min_samples_split= 10)
rfr=RandomForestRegressor(bootstrap= True, max_features= 'sqrt', min_samples_split= 2, n_estimators= 20)
ad=AdaBoostRegressor(n_estimators=2)
rg=Ridge(alpha= 0.0001, fit_intercept= False, solver= 'saga')

# %%
models=[]
models.append(('KNeighborsRegressor',knr))
models.append(('SupportVectorMachine',svr))
models.append(('LinearRegressor',lr))
models.append(('DecisionTreeRegressor',dtr))
models.append(('RandomForestRegressor',rfr))
models.append(('AdaBoostRegressor',ad))
models.append(('Ridge',rg))

# %%
from sklearn.metrics import mean_squared_error,mean_absolute_error
from sklearn.metrics import r2_score

# %%
Model=[]
sco=[]
r2score=[]
cvs=[]

for name,model in models:
    print('************',name,'************')
    print('\n')
    Model.append(name)
    model.fit(x_train,y_train) 
    
    print(model)
    score=model.score(x_train,y_train)
    score1=score.mean()
    pre=model.predict(x_test)
    print('\n')    
    sco.append(score1)
    print('score:',score1)
    MSE=mean_squared_error(y_test,pre)
    print('mean squared error',MSE)
    MAE=mean_absolute_error(y_test,pre)
    print('mean absolute error',MAE)
    R2score= r2_score(y_test,pre)
    print('r2_score',R2score)
    r2score.append(R2score*100)
    print('\n')
    sc=cross_val_score(model,x,y,cv=5).mean()
    print('Cross_Val_Score=',sc)
    cvs.append(sc*100)
    print('\n')
# Out:
# ************ KNeighborsRegressor ************
#
#
# KNeighborsRegressor(algorithm='auto', leaf_size=30, metric='minkowski',
#                     metric_params=None, n_jobs=None, n_neighbors=1, p=2,
#                     weights='uniform')
#
#
# score: 1.0
# mean squared error 5427806.846153846
# mean absolute error 1101.3846153846155
# r2_score 0.9967545893295015
#
#
# Cross_Val_Score= -1.5867700522149413
#
#
# ************ SupportVectorMachine ************
#
#
# SVR(C=10, cache_size=200, coef0=0.0, degree=3, epsilon=0.1, gamma='scale',
#     kernel='linear', max_iter=-1, shrinking=True, tol=0.001, verbose=False)
#
#
# score: -39.439211902235215
# mean squared error 49959314207.32692
# mean absolute error 219974.61538461538
# r2_score -28.87182411145356
#
#
# Cross_Val_Score= -3140298132.0004396
#
#
# ************ LinearRegressor ************
#
#
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None, normalize=False)
#
#
# score: 0.5857450909172772
# ...

# %%
result=pd.DataFrame({'Model':Model,'score':sco,'R2_score':r2score,'Cross_val_score':cvs})
result
# Out:
#                    Model      score     R2_score  Cross_val_score
# 0    KNeighborsRegressor   1.000000    99.675459    -1.586770e+02
# 1   SupportVectorMachine -39.439212 -2887.182411    -3.140298e+11
# 2        LinearRegressor   0.585745    58.869712    -2.284699e+10
# 3  DecisionTreeRegressor   0.820930    79.978937    -9.396921e+03
# 4  RandomForestRegressor   0.999456    99.870116    -1.828138e+02
# 5      AdaBoostRegressor   0.987674    97.914161    -8.210069e+06
# 6                  Ridge   0.000036    -0.064449    -7.953032e+09

# %% [markdown]
# Observation: On observing the above table we get to know that KNR gives better results.

# %%
#saving the model
from sklearn.externals import joblib
joblib.dump(knr,'covid.pkl')
# Out:
# ['covid.pkl']
