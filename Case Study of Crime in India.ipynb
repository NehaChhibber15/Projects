# %%
#installing libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
#Reading datasets
ds1=pd.read_csv("01_District_wise_crimes_committed_IPC_2001_2012.csv")
ds2=pd.read_csv("01_District_wise_crimes_committed_IPC_2013.csv")

# %%
#joining both the datasets into one dataset
df=pd.concat([ds1,ds2])
df
# Out:
#            STATE/UT       DISTRICT  YEAR  MURDER  ATTEMPT TO MURDER  \
# 0    ANDHRA PRADESH       ADILABAD  2001     101                 60
# 1    ANDHRA PRADESH      ANANTAPUR  2001     151                125
# 2    ANDHRA PRADESH       CHITTOOR  2001     101                 57
# 3    ANDHRA PRADESH       CUDDAPAH  2001      80                 53
# 4    ANDHRA PRADESH  EAST GODAVARI  2001      82                 67
# ..              ...            ...   ...     ...                ...
# 818     Lakshadweep    LAKSHADWEEP  2013       0                  0
# 819     Lakshadweep       ZZ TOTAL  2013       0                  0
# 820      Puducherry       KARAIKAL  2013       6                  3
# 821      Puducherry     PUDUCHERRY  2013      25                  8
# 822      Puducherry       ZZ TOTAL  2013      31                 11
#
#      CULPABLE HOMICIDE NOT AMOUNTING TO MURDER  RAPE  CUSTODIAL RAPE  \
# 0                                           17    50               0
# ...

# %%
#finding column present in the dataset
df.columns
# Out:
# Index(['STATE/UT', 'DISTRICT', 'YEAR', 'MURDER', 'ATTEMPT TO MURDER',
#        'CULPABLE HOMICIDE NOT AMOUNTING TO MURDER', 'RAPE', 'CUSTODIAL RAPE',
#        'OTHER RAPE', 'KIDNAPPING & ABDUCTION',
#        'KIDNAPPING AND ABDUCTION OF WOMEN AND GIRLS',
#        'KIDNAPPING AND ABDUCTION OF OTHERS', 'DACOITY',
#        'PREPARATION AND ASSEMBLY FOR DACOITY', 'ROBBERY', 'BURGLARY', 'THEFT',
#        'AUTO THEFT', 'OTHER THEFT', 'RIOTS', 'CRIMINAL BREACH OF TRUST',
#        'CHEATING', 'COUNTERFIETING', 'ARSON', 'HURT/GREVIOUS HURT',
#        'DOWRY DEATHS', 'ASSAULT ON WOMEN WITH INTENT TO OUTRAGE HER MODESTY',
#        'INSULT TO MODESTY OF WOMEN', 'CRUELTY BY HUSBAND OR HIS RELATIVES',
#        'IMPORTATION OF GIRLS FROM FOREIGN COUNTRIES',
#        'CAUSING DEATH BY NEGLIGENCE', 'OTHER IPC CRIMES', 'TOTAL IPC CRIMES'],
#       dtype='object')

# %%
#finding information about the dataset
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 9840 entries, 0 to 822
# Data columns (total 33 columns):
#  #   Column                                               Non-Null Count  Dtype
# ---  ------                                               --------------  -----
#  0   STATE/UT                                             9840 non-null   object
#  1   DISTRICT                                             9840 non-null   object
#  2   YEAR                                                 9840 non-null   int64
#  3   MURDER                                               9840 non-null   int64
#  4   ATTEMPT TO MURDER                                    9840 non-null   int64
#  5   CULPABLE HOMICIDE NOT AMOUNTING TO MURDER            9840 non-null   int64
#  6   RAPE                                                 9840 non-null   int64
#  7   CUSTODIAL RAPE                                       9840 non-null   int64
# ...

# %% [markdown]
# Observation: On observing the given info we find out that there are two object type data rest all are int type.

# %%
#finding null values
df.isnull().sum()
# Out:
# STATE/UT                                               0
# DISTRICT                                               0
# YEAR                                                   0
# MURDER                                                 0
# ATTEMPT TO MURDER                                      0
# CULPABLE HOMICIDE NOT AMOUNTING TO MURDER              0
# RAPE                                                   0
# CUSTODIAL RAPE                                         0
# OTHER RAPE                                             0
# KIDNAPPING & ABDUCTION                                 0
# KIDNAPPING AND ABDUCTION OF WOMEN AND GIRLS            0
# KIDNAPPING AND ABDUCTION OF OTHERS                     0
# DACOITY                                                0
# PREPARATION AND ASSEMBLY FOR DACOITY                   0
# ROBBERY                                                0
# BURGLARY                                               0
# ...

# %% [markdown]
# Observation: There is no null value present in any attribute.

# %%
#finding correlation between the columns
df.corr()
# Out:
#                                                         YEAR    MURDER  \
# YEAR                                                1.000000 -0.014588
# MURDER                                             -0.014588  1.000000
# ATTEMPT TO MURDER                                   0.002504  0.957058
# CULPABLE HOMICIDE NOT AMOUNTING TO MURDER          -0.007766  0.783331
# RAPE                                                0.042352  0.804640
# CUSTODIAL RAPE                                     -0.004074  0.147950
# OTHER RAPE                                          0.042357  0.804615
# KIDNAPPING & ABDUCTION                              0.074994  0.812158
# KIDNAPPING AND ABDUCTION OF WOMEN AND GIRLS         0.087115  0.769808
# KIDNAPPING AND ABDUCTION OF OTHERS                  0.024376  0.779709
# DACOITY                                            -0.035842  0.790893
# PREPARATION AND ASSEMBLY FOR DACOITY                0.016628  0.422544
# ...

# %%
#finding correlation by using heatmap
plt.subplots(figsize=(25,15)) 
sns.heatmap(df.corr(),annot=True)

# %% [markdown]
# Observation: On observing the given heatmap we get to know that crime has very less correlation with year, importing girls from other countries and CUSTODIAL Rape  where as other columns are highly correlated with increase in crime.

# %%
#finding number of entries for each state
df['STATE/UT'].value_counts()
# Out:
# UTTAR PRADESH     878
# MADHYA PRADESH    628
# MAHARASHTRA       552
# BIHAR             540
# TAMIL NADU        469
#                  ...
# Goa                 3
# Daman & Diu         3
# Lakshadweep         2
# Chandigarh          2
# D&N Haveli          2
# Name: STATE/UT, Length: 70, dtype: int64

# %%
#finding shape of the dataset
df.shape
# Out:
# (9840, 33)

# %%
#finding min and maximum values in the given dataset by using describe method
df.describe().T
# Out:
#                                                      count         mean  \
# YEAR                                                9840.0  2007.161890
# MURDER                                              9840.0    88.565854
# ATTEMPT TO MURDER                                   9840.0    78.738618
# CULPABLE HOMICIDE NOT AMOUNTING TO MURDER           9840.0     9.754878
# RAPE                                                9840.0    55.456098
# CUSTODIAL RAPE                                      9840.0     0.005488
# OTHER RAPE                                          9840.0    55.450610
# KIDNAPPING & ABDUCTION                              9840.0    85.836992
# KIDNAPPING AND ABDUCTION OF WOMEN AND GIRLS         9840.0    64.184553
# KIDNAPPING AND ABDUCTION OF OTHERS                  9840.0    21.652439
# DACOITY                                             9840.0    12.997561
# PREPARATION AND ASSEMBLY FOR DACOITY                9840.0     7.134146
# ...

# %% [markdown]
# Observation: finding minimum and maximum value of each type of crime cases.We find out that maximum cases are of Hurt/Grevious hurt type.

# %%
for i in df.describe().columns:
    sns.boxplot(df[i])
    plt.show()

# %% [markdown]
# Observation: On observing the above boxplot. we get to know that data is skewed. All the data is aligned towards left.

# %%
#rename the state/UT column to STATE
df.rename(columns={'STATE/UT':'STATE'},inplace=True)

# %%
#collect the state names in a list and print
states=df.STATE.unique()
print(states)
# Out:
# ['ANDHRA PRADESH' 'ARUNACHAL PRADESH' 'ASSAM' 'BIHAR' 'CHHATTISGARH' 'GOA'
#  'GUJARAT' 'HARYANA' 'HIMACHAL PRADESH' 'JAMMU & KASHMIR' 'JHARKHAND'
#  'KARNATAKA' 'KERALA' 'MADHYA PRADESH' 'MAHARASHTRA' 'MANIPUR' 'MEGHALAYA'
#  'MIZORAM' 'NAGALAND' 'ODISHA' 'PUNJAB' 'RAJASTHAN' 'SIKKIM' 'TAMIL NADU'
#  'TRIPURA' 'UTTAR PRADESH' 'UTTARAKHAND' 'WEST BENGAL' 'A & N ISLANDS'
#  'CHANDIGARH' 'D & N HAVELI' 'DAMAN & DIU' 'DELHI UT' 'LAKSHADWEEP'
#  'PUDUCHERRY' 'Andhra Pradesh' 'Arunachal Pradesh' 'Assam' 'Bihar'
#  'Chhattisgarh' 'Goa' 'Gujarat' 'Haryana' 'Himachal Pradesh'
#  'Jammu & Kashmir' 'Jharkhand' 'Karnataka' 'Kerala' 'Madhya Pradesh'
#  'Maharashtra' 'Manipur' 'Meghalaya' 'Mizoram' 'Nagaland' 'Odisha'
#  'Punjab' 'Rajasthan' 'Sikkim' 'Tamil Nadu' 'Tripura' 'Uttar Pradesh'
#  'Uttarakhand' 'West Bengal' 'A&N Islands' 'Chandigarh' 'D&N Haveli'
#  'Daman & Diu' 'Delhi UT' 'Lakshadweep' 'Puducherry']

# %%
#data cleaning on state names
for i in range(0,len(states)):
    states[i]=states[i].lower()
    for j in range(0,len(states)):
        if states[j] =='a & n islands':
            states[j]=='a&n islands'
        if states[j] == 'd & n haveli':
            states[j]=='d&n islands'

# %%
print(states)
# Out:
# ['andhra pradesh' 'arunachal pradesh' 'assam' 'bihar' 'chhattisgarh' 'goa'
#  'gujarat' 'haryana' 'himachal pradesh' 'jammu & kashmir' 'jharkhand'
#  'karnataka' 'kerala' 'madhya pradesh' 'maharashtra' 'manipur' 'meghalaya'
#  'mizoram' 'nagaland' 'odisha' 'punjab' 'rajasthan' 'sikkim' 'tamil nadu'
#  'tripura' 'uttar pradesh' 'uttarakhand' 'west bengal' 'a & n islands'
#  'chandigarh' 'd & n haveli' 'daman & diu' 'delhi ut' 'lakshadweep'
#  'puducherry' 'andhra pradesh' 'arunachal pradesh' 'assam' 'bihar'
#  'chhattisgarh' 'goa' 'gujarat' 'haryana' 'himachal pradesh'
#  'jammu & kashmir' 'jharkhand' 'karnataka' 'kerala' 'madhya pradesh'
#  'maharashtra' 'manipur' 'meghalaya' 'mizoram' 'nagaland' 'odisha'
#  'punjab' 'rajasthan' 'sikkim' 'tamil nadu' 'tripura' 'uttar pradesh'
#  'uttarakhand' 'west bengal' 'a&n islands' 'chandigarh' 'd&n haveli'
#  'daman & diu' 'delhi ut' 'lakshadweep' 'puducherry']

# %%
#removing duplicate state names from the list
states=np.unique(states).tolist()
print(states)
# Out:
# ['a & n islands', 'a&n islands', 'andhra pradesh', 'arunachal pradesh', 'assam', 'bihar', 'chandigarh', 'chhattisgarh', 'd & n haveli', 'd&n haveli', 'daman & diu', 'delhi ut', 'goa', 'gujarat', 'haryana', 'himachal pradesh', 'jammu & kashmir', 'jharkhand', 'karnataka', 'kerala', 'lakshadweep', 'madhya pradesh', 'maharashtra', 'manipur', 'meghalaya', 'mizoram', 'nagaland', 'odisha', 'puducherry', 'punjab', 'rajasthan', 'sikkim', 'tamil nadu', 'tripura', 'uttar pradesh', 'uttarakhand', 'west bengal']

# %%
#convert the state names to lower case
df['STATE'] = df['STATE'].str.lower()

# %%
df.head()
# Out:
#             STATE       DISTRICT  YEAR  MURDER  ATTEMPT TO MURDER  \
# 0  andhra pradesh       ADILABAD  2001     101                 60
# 1  andhra pradesh      ANANTAPUR  2001     151                125
# 2  andhra pradesh       CHITTOOR  2001     101                 57
# 3  andhra pradesh       CUDDAPAH  2001      80                 53
# 4  andhra pradesh  EAST GODAVARI  2001      82                 67
#
#    CULPABLE HOMICIDE NOT AMOUNTING TO MURDER  RAPE  CUSTODIAL RAPE  \
# 0                                         17    50               0
# 1                                          1    23               0
# 2                                          2    27               0
# 3                                          1    20               0
# 4                                          1    23               0
#
#    OTHER RAPE  KIDNAPPING & ABDUCTION  ...  ARSON  HURT/GREVIOUS HURT  \
# 0          50                      46  ...     30                1131
# ...

# %%
#filter out the total crime for each state
df_total=df[df['DISTRICT']=='TOTAL']

# %%
df_total
# Out:
#                   STATE DISTRICT  YEAR  MURDER  ATTEMPT TO MURDER  \
# 28       andhra pradesh    TOTAL  2001    2602               1555
# 42    arunachal pradesh    TOTAL  2001      83                 53
# 70                assam    TOTAL  2001    1356                481
# 115               bihar    TOTAL  2001    3643               3419
# 135        chhattisgarh    TOTAL  2001     880                529
# ...                 ...      ...   ...     ...                ...
# 8988         chandigarh    TOTAL  2012      21                 44
# 8990       d & n haveli    TOTAL  2012       7                  2
# 8993        daman & diu    TOTAL  2012       3                  5
# 9013        lakshadweep    TOTAL  2012       0                  0
# 9016         puducherry    TOTAL  2012      29                 27
#
#       CULPABLE HOMICIDE NOT AMOUNTING TO MURDER  RAPE  CUSTODIAL RAPE  \
# 28                                          136   871               0
# ...

# %%
#droping district column as it is not impacting the result differently, then it make no use to retain that column.
df_total.drop('DISTRICT',axis=1, inplace=True)
# Out:
# C:\Users\Suncity\anaconda3\lib\site-packages\pandas\core\frame.py:3997: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   errors=errors,

# %%
#filter out the total crimes for each state&UT for the year 2001 and 2012. Building an understanding that how this time span impacting the crime rate in cities
df_total_2001=df_total[df_total['YEAR']==2001]
df_total_2012=df_total[df_total['YEAR']==2012]

# %%
#dropping year column. As it makes no use here.
df_total_2001.drop('YEAR',axis=1,inplace=True)
df_total_2012.drop('YEAR',axis=1,inplace=True)

# %%
df_total_2001
# Out:
#                  STATE  MURDER  ATTEMPT TO MURDER  \
# 28      andhra pradesh    2602               1555
# 42   arunachal pradesh      83                 53
# 70               assam    1356                481
# 115              bihar    3643               3419
# 135       chhattisgarh     880                529
# 138                goa      36                 30
# 169            gujarat    1226                537
# 190            haryana     781                467
# 204   himachal pradesh     119                 75
# 228    jammu & kashmir    1075               1474
# 253          jharkhand    1507                866
# 285          karnataka    1626               1475
# 302             kerala     472                615
# 351     madhya pradesh    2425               2870
# 397        maharashtra    2839               1454
# 407            manipur     209                168
# 415          meghalaya     164                 47
# 424            mizoram      31                 15
# ...

# %%
#Visualizing the data of 2001 by using piechart. 
import matplotlib.pyplot as plt
plt.figure(figsize=(15,15))
my_data = df_total_2001['TOTAL IPC CRIMES']
my_labels = df_total_2001['STATE']

plt.pie(my_data,labels=my_labels,startangle=15,autopct='%1.1f%%')
plt.title('Crime Rate in 2001')
plt.axis('equal')
plt.xticks(rotation=60)
plt.show()

# %% [markdown]
# Observation: On observing the given pie char.We get to know that in 2001,the maximum crime rate is in madhya Pardesh, Uttar pardesh, maharastra,rajasthan and tamil nadu. Where there was no crime in sikkim

# %%
#Visualizing the data of 2012 by using piechart. 
import matplotlib.pyplot as plt
plt.figure(figsize=(15,15))
my_data = df_total_2012['TOTAL IPC CRIMES']
my_labels = df_total_2012['STATE']

plt.pie(my_data,labels=my_labels,startangle=15,autopct='%1.1f%%')
plt.title('Crime Rate in 2012')
plt.axis('equal')
plt.xticks(rotation=60)
plt.show()

# %% [markdown]
# Observation: In 2012, we get to know that there is a little downfall in the crime rate of major cities like Maharastra, Madhyapardesh, Uttar pardesh. May be there are some improvization in rules and regulation against crime in cities.

# %%
#Data of Rape crime committed in the year 2001 per state
x= df_total_2001['STATE']
y= df_total_2001['RAPE']

# %%
plt.figure(figsize=(13,9))
plt.xlabel("State")
plt.ylabel("Rape Cases")
plt.title("State vs Rape Cases")
sns.scatterplot(x,y,hue='STATE',data=df_total_2001)
plt.xticks(rotation=90)
plt.show()

# %% [markdown]
# Observation:In 2001,Madhya Pardesh and Maharastra have higher number of rape cases. May be their govt is not taking any strict measures.

# %%
x1= df_total_2012['STATE']
y1= df_total_2012['RAPE']

plt.figure(figsize=(13,9))
plt.xlabel("State")
plt.ylabel("Rape Cases")
plt.title("State vs Rape Cases")
sns.barplot(x1,y1,hue='STATE',data=df_total_2012)
plt.xticks(rotation=90)
plt.show()

# %% [markdown]
# Observation: In 2012, Madhya Pardesh, Maharastra, Rajasthan and West bengal has more number of rape cases. Where as it is higher as compare to 2001. That means crime against women is rapidly increasing in these metropolitian cities.

# %%
#Visualizing crime over the years by using bar graph
df_total_pivot=\
df_total.pivot_table(index='YEAR',values="TOTAL IPC CRIMES")
df_total_pivot.plot(kind='bar',color='brown',figsize=(12,7))
plt.xlabel("YEAR")
plt.ylabel("TOTAL IPC CRIMES Rate")
plt.title("YEAR and TOTAL IPC CRIMES ")
plt.xticks(rotation=0)
plt.show()

# %% [markdown]
# Observation: From the above graph we observed that the crime rate is increases from 2001 to 2012. May be the impact of poverty and unemployment on the crime rate.

# %%
df_total
# Out:
#                   STATE  YEAR  MURDER  ATTEMPT TO MURDER  \
# 28       andhra pradesh  2001    2602               1555
# 42    arunachal pradesh  2001      83                 53
# 70                assam  2001    1356                481
# 115               bihar  2001    3643               3419
# 135        chhattisgarh  2001     880                529
# ...                 ...   ...     ...                ...
# 8988         chandigarh  2012      21                 44
# 8990       d & n haveli  2012       7                  2
# 8993        daman & diu  2012       3                  5
# 9013        lakshadweep  2012       0                  0
# 9016         puducherry  2012      29                 27
#
#       CULPABLE HOMICIDE NOT AMOUNTING TO MURDER  RAPE  CUSTODIAL RAPE  \
# 28                                          136   871               0
# 42                                            3    33               0
# ...

# %%
#Using label encoder to convert all categorical data into 0 or 1
from sklearn.preprocessing import LabelEncoder
label= LabelEncoder()

# %%
varib=['STATE','YEAR']
for i in varib:
    df_total[i]=label.fit_transform(df_total[i])
# Out:
# C:\Users\Suncity\anaconda3\lib\site-packages\ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   This is separate from the ipykernel package so we can avoid doing imports until

# %%
df_total
# Out:
#       STATE  YEAR  MURDER  ATTEMPT TO MURDER  \
# 28        1     0    2602               1555
# 42        2     0      83                 53
# 70        3     0    1356                481
# 115       4     0    3643               3419
# 135       6     0     880                529
# ...     ...   ...     ...                ...
# 8988      5    11      21                 44
# 8990      7    11       7                  2
# 8993      8    11       3                  5
# 9013     17    11       0                  0
# 9016     25    11      29                 27
#
#       CULPABLE HOMICIDE NOT AMOUNTING TO MURDER  RAPE  CUSTODIAL RAPE  \
# 28                                          136   871               0
# 42                                            3    33               0
# 70                                           40   817               0
# 115                                         250   888               0
# ...

# %%
x=df_total.iloc[:,0:-1]
x
# Out:
#       STATE  YEAR  MURDER  ATTEMPT TO MURDER  \
# 28        1     0    2602               1555
# 42        2     0      83                 53
# 70        3     0    1356                481
# 115       4     0    3643               3419
# 135       6     0     880                529
# ...     ...   ...     ...                ...
# 8988      5    11      21                 44
# 8990      7    11       7                  2
# 8993      8    11       3                  5
# 9013     17    11       0                  0
# 9016     25    11      29                 27
#
#       CULPABLE HOMICIDE NOT AMOUNTING TO MURDER  RAPE  CUSTODIAL RAPE  \
# 28                                          136   871               0
# 42                                            3    33               0
# 70                                           40   817               0
# 115                                         250   888               0
# ...

# %%
y=df_total.iloc[:,-1]
y
# Out:
# 28      130089
# 42        2342
# 70       36877
# 115      88432
# 135      38460
#          ...
# 8988      3606
# 8990       318
# 8993       239
# 9013        60
# 9016      4281
# Name: TOTAL IPC CRIMES, Length: 408, dtype: int64

# %%
#Training of model by using sklearn library
import sklearn

from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_squared_error,mean_absolute_error

# %%
#creating train test split
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=.33,random_state=42)

# %%
#importing linear Regression model. As the data is skewed. So we need to normalize it.
lm=LinearRegression(normalize=True)
lm.fit(x_train,y_train)
lm.score(x_train,y_train)
# Out:
# 1.0

# %%
#Checking the model efficiency by using cross_val_score
from sklearn.model_selection import cross_val_score

# %%
#lets use grid_search to find optimal value of n_neighbors for KNN model
from sklearn.model_selection import GridSearchCV
from sklearn.neighbors import KNeighborsRegressor
neighbors={"n_neighbors":range(1,30)}
knr=KNeighborsRegressor()
gknr=GridSearchCV(knr,neighbors,cv=10)
gknr.fit(x,y)
gknr.best_params_
# Out:
# {'n_neighbors': 3}

# %%
#importing algorithms
from sklearn.svm import SVR
from sklearn.tree import DecisionTreeRegressor
from sklearn.ensemble import RandomForestRegressor
from sklearn.ensemble import AdaBoostRegressor

# %%
#finding best parameter for RandomForestRegressor by using gridsearch cv
from sklearn.metrics import mean_squared_error,mean_absolute_error
from sklearn.metrics import r2_score
def Grid_Search_CV_RFR(x_train, y_train):
    from sklearn.model_selection import GridSearchCV
    from sklearn.model_selection import ShuffleSplit
    from sklearn.ensemble import RandomForestRegressor

    estimator = RandomForestRegressor()
    param_grid = { 
            "n_estimators"      : [10,20,30],
            "max_features"      : ["auto", "sqrt", "log2"],
            "min_samples_split" : [2,4,8],
            "bootstrap": [True, False],
            }

    grid = GridSearchCV(estimator, param_grid, n_jobs=-1, cv=5)

    grid.fit(x_train, y_train)

    return grid.best_score_ , grid.best_params_

# %%
def RFR(x_train, x_test, y_train, y_test, best_params):
    from sklearn.ensemble import RandomForestRegressor
    estimator = RandomForestRegressor(n_jobs=-1).set_params(**best_params)
    estimator.fit(x_train,y_train)
    y_predict = estimator.predict(x_test)
    print ("R2 score:",r2_score(y_test,y_predict))
    return y_test,y_predict

# %%
for i in range(5):
    print ("Loop: " , i)
    print ("--------------") 
    x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.2)
    best_score, best_params = Grid_Search_CV_RFR(x_train, y_train)
    y_test , y_predict = RFR(x_train, x_test, y_train, y_test, best_params)
    print ("Best Score:" ,best_score)
    print ("Best params:",best_params)
# Out:
# Loop:  0
# --------------
# R2 score: 0.9956684897068702
# Best Score: 0.9941074947721559
# Best params: {'bootstrap': False, 'max_features': 'sqrt', 'min_samples_split': 2, 'n_estimators': 20}
# Loop:  1
# --------------
# R2 score: 0.9834102097311553
# Best Score: 0.9956117502311421
# Best params: {'bootstrap': False, 'max_features': 'sqrt', 'min_samples_split': 2, 'n_estimators': 20}
# Loop:  2
# --------------
# R2 score: 0.9966906385053589
# Best Score: 0.9939836666728199
# Best params: {'bootstrap': True, 'max_features': 'auto', 'min_samples_split': 2, 'n_estimators': 30}
# Loop:  3
# --------------
# R2 score: 0.99547020636017
# Best Score: 0.9947641629020787
# Best params: {'bootstrap': False, 'max_features': 'sqrt', 'min_samples_split': 4, 'n_estimators': 20}
# Loop:  4
# --------------
# R2 score: 0.9967265379319947
# Best Score: 0.9938235421615346
# Best params: {'bootstrap': False, 'max_features': 'log2', 'min_samples_split': 2, 'n_estimators': 30}

# %%
dtm = DecisionTreeRegressor(max_depth=4,
                           min_samples_split=5,
                           max_leaf_nodes=10)


param_grid = {"criterion": ["mse", "mae"],
              "min_samples_split": [10, 20, 40],
              "max_depth": [2, 6, 8],
              "min_samples_leaf": [20, 40, 100],
              "max_leaf_nodes": [5, 20, 100],
              }

## Comment in order to publish in kaggle.

grid_cv_dtm = GridSearchCV(dtm, param_grid, cv=5)

grid_cv_dtm.fit(x,y)
print("R-Squared::{}".format(grid_cv_dtm.best_score_))
print("Best Hyperparameters::\n{}".format(grid_cv_dtm.best_params_))
# Out:
# R-Squared::0.9558561466843628
# Best Hyperparameters::
# {'criterion': 'mse', 'max_depth': 8, 'max_leaf_nodes': 20, 'min_samples_leaf': 20, 'min_samples_split': 40}

# %%
#finding best parameter for adaboost by using grid search cv
from sklearn.ensemble import AdaBoostRegressor
n_estimators={"n_estimators":range(1,30)}
ad=AdaBoostRegressor()
gad=GridSearchCV(ad,n_estimators,cv=10)
gad.fit(x,y)
gad.best_params_
# Out:
# {'n_estimators': 26}

# %%
#applying for loop for all the models
from sklearn.linear_model import LinearRegression
knr=KNeighborsRegressor(n_neighbors=3)
svr=SVR(C= 10, kernel= 'rbf')
lm=LinearRegression(normalize=True)
dtr=DecisionTreeRegressor(criterion= 'mse', max_depth= 8, max_leaf_nodes= 20, min_samples_leaf= 20, min_samples_split= 20)
rfr=RandomForestRegressor(bootstrap= False, max_features= 'sqrt', min_samples_split= 2, n_estimators= 20)
ad=AdaBoostRegressor(n_estimators=28)

# %%
models=[]
models.append(('KNeighborsRegressor',knr))
models.append(('SupportVectorMachine',svr))
models.append(('LinearRegressor',lm))
models.append(('DecisionTreeRegressor',dtr))
models.append(('RandomForestRegressor',rfr))
models.append(('AdaBoostRegressor',ad))

# %%
from sklearn.metrics import mean_squared_error,mean_absolute_error
from sklearn.metrics import r2_score

# %%
Model=[]
sco=[]
r2score=[]
cvs=[]

for name,model in models:
    print('************',name,'************')
    print('\n')
    Model.append(name)
    model.fit(x_train,y_train) 
    
    print(model)
    score=model.score(x_train,y_train)
    score1=score.mean()
    pre=model.predict(x_test)
    print('\n')    
    sco.append(score1)
    print('score:',score1)
    MSE=mean_squared_error(y_test,pre)
    print('mean squared error',MSE)
    MAE=mean_absolute_error(y_test,pre)
    print('mean absolute error',MAE)
    R2score= r2_score(y_test,pre)
    print('r2_score',R2score)
    r2score.append(R2score*100)
    print('\n')
    sc=cross_val_score(model,x,y,cv=10).mean()
    print('Cross_Val_Score=',sc)
    cvs.append(sc*100)
    print('\n')
# Out:
# ************ KNeighborsRegressor ************
#
#
# KNeighborsRegressor(algorithm='auto', leaf_size=30, metric='minkowski',
#                     metric_params=None, n_jobs=None, n_neighbors=3, p=2,
#                     weights='uniform')
#
#
# score: 0.9976611472329984
# mean squared error 14375981.281842817
# mean absolute error 2088.1382113821137
# r2_score 0.9973122292970176
#
#
# Cross_Val_Score= 0.9955964030476295
#
#
# ************ SupportVectorMachine ************
#
#
# SVR(C=10, cache_size=200, coef0=0.0, degree=3, epsilon=0.1, gamma='scale',
#     kernel='rbf', max_iter=-1, shrinking=True, tol=0.001, verbose=False)
#
#
# score: -0.19133717518238336
# mean squared error 6565400516.647879
# mean absolute error 58491.14887715933
# r2_score -0.227484288970198
#
#
# Cross_Val_Score= -0.20585060143604156
#
#
# ************ LinearRegressor ************
#
#
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None, normalize=True)
#
#
# score: 1.0
# ...

# %%
result=pd.DataFrame({'Model':Model,'score':sco,'R2_score':r2score,'Cross_val_score':cvs})
result
# Out:
#                    Model     score    R2_score  Cross_val_score
# 0    KNeighborsRegressor  0.997661   99.731223        99.559640
# 1   SupportVectorMachine -0.191337  -22.748429       -20.585060
# 2        LinearRegressor  1.000000  100.000000       100.000000
# 3  DecisionTreeRegressor  0.972053   98.240509        97.439492
# 4  RandomForestRegressor  1.000000   99.668017        99.496445
# 5      AdaBoostRegressor  0.992026   99.162703        98.713423

# %% [markdown]
# Observation: from the above table we know that we get maximum score with Linear Regressor.

# %%
#saving the model
from sklearn.externals import joblib
joblib.dump(lm,'crime.pkl')
# Out:
# C:\Users\Suncity\anaconda3\lib\site-packages\sklearn\externals\joblib\__init__.py:15: FutureWarning: sklearn.externals.joblib is deprecated in 0.21 and will be removed in 0.23. Please import this functionality directly from joblib, which can be installed with: pip install joblib. If this warning is raised when loading pickled models, you may need to re-serialize those models with scikit-learn 0.21+.
#   warnings.warn(msg, category=FutureWarning)
# ['crime.pkl']
